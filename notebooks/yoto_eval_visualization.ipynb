# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('~/Downloads/acoustic-ambrosial-wolf-of-debate_results.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d626e7a5176f> in <module>
# ----> 1 df = pd.read_csv('~/Downloads/acoustic-ambrosial-wolf-of-debate_results.csv', index=False)
#       2
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
alpha_lambda_df = df.groupby(['alpha', 'lambda']).mean()
alpha_lambda_df.reset_index(inplace=True, drop=True)

# %%
plt.(alpha_lambda_df)
